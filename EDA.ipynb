# %% [markdown]
# <a href="https://colab.research.google.com/github/Zainabb110/CS584-Project/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive 
drive.mount('/content/gdrive')

expenses = pd.read_csv('gdrive/My Drive/Colab Notebooks/expenses.csv')
# Out:
# Mounted at /content/gdrive

# %%
expenses.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
expenses.shape
# Out:
# (1338, 7)

# %%
expenses.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
import matplotlib.pyplot as plt
plt.plot(expenses.age, expenses.charges, 'o' )
plt.xlabel('Age')
plt.ylabel('Expenses')
# Out:
# Text(0, 0.5, 'Expenses')

# %%
smoker = expenses.smoker == "yes" 
#expenses.shape
#print(smoker)
#nonsmoker = expenses[expenses["smoker" == 'no']]
# print(smoker[0])
# for i in range(len(smoker)):
#   if smoker[i] == True:
#     smoker[i] = 'orange'
for i in expenses:
  print(i)
plt.plot(expenses.age, expenses.charges, 'o')
plt.xlabel('Age')
plt.ylabel('Expenses')
# Out:
# age
# sex
# bmi
# children
# smoker
# region
# charges
# Text(0, 0.5, 'Expenses')

# %%
plt.plot(expenses.bmi, expenses.charges, 'o' )
plt.xlabel('BMI')
plt.ylabel('Expenses')
# Out:
# Text(0, 0.5, 'Expenses')

# %%
plt.plot(expenses.children, expenses.charges, 'o' )
plt.xlabel('Children')
plt.ylabel('Expenses')
# Out:
# Text(0, 0.5, 'Expenses')

# %%
plt.bar(expenses.children, expenses.charges)
plt.xlabel('Children')
plt.ylabel('Expenses')
# Out:
# Text(0, 0.5, 'Expenses')

# %%
x = []
for i in range(len(expenses.charges)):
  x.append(i)

female = expenses.sex == 'female'
print(female)
plt.scatter(x, expenses.charges, c = female)
#plt.xlabel('Gender')
plt.ylabel('Expenses')
plt.title("Expenses v/s Gender")
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334     True
# 1335     True
# 1336     True
# 1337     True
# Name: sex, Length: 1338, dtype: bool
# Text(0.5, 1.0, 'Expenses v/s Gender')

# %%
plt.bar(expenses.smoker, expenses.charges)
plt.xlabel('Smoker')
plt.ylabel('Expenses')
# Out:
# Text(0, 0.5, 'Expenses')

# %%
plt.bar(expenses.region, expenses.charges)
plt.xlabel('Region')
plt.ylabel('Expenses')
# Out:
# Text(0, 0.5, 'Expenses')

# %%
import seaborn
seaborn.pairplot(expenses)

# %%
seaborn.pairplot(expenses,x_vars=['age','children', 'bmi'],y_vars=['charges'],hue='smoker')
seaborn.pairplot(expenses,x_vars=['age','children', 'bmi'],y_vars=['charges'],hue='sex')
seaborn.pairplot(expenses,x_vars=['age','children', 'bmi'],y_vars=['charges'],hue='region')
